# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.2f}".format)

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from src.data_pipeline import run_pipeline

raw_file_path = "../data/raw/online_retail.csv"
cleaned_file_path = "../data/processed/online_retail_cleaned.csv"

cleaned_df = run_pipeline(raw_file_path, cleaned_file_path)

cleaned_df.head()
# Out:
# Rows before cleaning: 541909
# Rows after cleaning: 536641
# Rows removed: 5268
# Number of cancellations: 9251
# Number of anonymous customers: 135037
# Cleaned data saved to ../data/processed/online_retail_cleaned.csv
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  IsCancellation  \
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom           False
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom           False
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom           False
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom           False
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom           False
#
#    TotalPrice  Year  Month  Day
# 0       15.30  2010     12    1
# 1       20.34  2010     12    1
# 2       22.00  2010     12    1
# 3       20.34  2010     12    1
# 4       20.34  2010     12    1
